# %%
import pandas as pd

# %%
"""
1. Creating Pandas Series Object
2. Creating Pandas DataFrame object
3. Indexing & Slicing of Series and DF
"""

# %%
names =['riya', 'rajiv', 'richa', 'ram']
series_n = pd.Series(names)
series_n
# Out:
# 0     riya
# 1    rajiv
# 2    richa
# 3      ram
# dtype: object

# %%
series_n.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
series_n.values
# Out:
# array(['riya', 'rajiv', 'richa', 'ram'], dtype=object)

# %%
count = {'USA' : 50, 'India': 500, 'UK' : 80, 'France': 90}
count = pd.Series(count)
count
# Out:
# USA        50
# India     500
# UK         80
# France     90
# dtype: int64

# %%
count.loc['India']
# Out:
# 500

# %%
count.iloc[1]
# Out:
# 500

# %%
head = {'USA' : 'NYC', 'India': 'Pune', 'UK' : 'London', 'France': 'Paris'}
head = pd.Series(head)
head
# Out:
# USA          NYC
# India       Pune
# UK        London
# France     Paris
# dtype: object

# %%
#combinng series data
df = pd.DataFrame({'Head Office': head, 'Employee Count': count})
df
# Out:
#        Head Office  Employee Count
# USA            NYC              50
# India         Pune             500
# UK          London              80
# France       Paris              90

# %%
df.loc['UK']
# Out:
# Head Office       London
# Employee Count        80
# Name: UK, dtype: object

# %%
df.loc[['UK', 'France']]
# Out:
#        Head Office  Employee Count
# UK          London              80
# France       Paris              90

# %%
df.loc['India': 'France']
# Out:
#        Head Office  Employee Count
# India         Pune             500
# UK          London              80
# France       Paris              90

# %%
df.loc['India': 'France','Employee Count']
# Out:
# India     500
# UK         80
# France     90
# Name: Employee Count, dtype: int64

# %%
df.loc['India': 'France', 'Head Office':'Employee Count']
# Out:
#        Head Office  Employee Count
# India         Pune             500
# UK          London              80
# France       Paris              90

# %%
df.loc['India': 'France', 'Head Office':'Employee Count']
# Out:
#        Head Office  Employee Count
# India         Pune             500
# UK          London              80
# France       Paris              90

# %%
df.loc['India': 'France', ['Head Office','Employee Count']]
# Out:
#        Head Office  Employee Count
# India         Pune             500
# UK          London              80
# France       Paris              90

# %%
df.iloc[1:3, [0,1]]
# Out:
#       Head Office  Employee Count
# India        Pune             500
# UK         London              80

# %%
data = {'Name' : ['Riya', 'Rajiv', 'Richa', 'Ram'],
       'Salary': [300000, 400000, 200000, 500000],
       'Dept' : ['Admin', 'IT', 'IT', 'HR']}
df = pd.DataFrame(data)
df
# Out:
#     Name  Salary   Dept
# 0   riya  300000  Admin
# 1  rajiv  400000     IT
# 2  richa  200000     IT
# 3    ram  500000     HR

# %%
df=df.set_index('Name')
df
# Out:
#        Salary   Dept
# Name
# riya   300000  Admin
# rajiv  400000     IT
# richa  200000     IT
# ram    500000     HR

# %%
# data - row data, index = labelled indices, columns = Col header
df= pd.DataFrame(data=[[500,35,23],[600,40,22],[300,25,25]],
                index=['Tata', 'Maruti', 'Honda'],
                columns=['Revenue', 'Market Share', 'Profit'])
df
# Out:
#         Revenue  Market Share  Profit
# Tata        500            35      23
# Maruti      600            40      22
# Honda       300            25      25
