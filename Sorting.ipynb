# %%
import pandas as pd

# %%
"""
1. sort_values(by=, ascending=)
2. nlargest()
3. nsmallest()
4. sort_index()
"""

# %%
df = pd.read_csv('Data.tsv', delimiter='\t')
df
# Out:
#                    Name                       Position         Office  Age  \
# 0            Airi Satou                     Accountant          Tokyo   33
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3         Bradley Greer              Software Engineer         London   41
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
df.sort_values(by='Age')
# Out:
#                    Name                       Position         Office  Age  \
# 48  Tatyana Fitzpatrick              Regional Director         London   19
# 45            Shou Itou             Regional Marketing          Tokyo   20
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 32           Lael Greer          Systems Administrator         London   21
# 18         Gavin Cortez                    Team Leader  San Francisco   22
# 40          Quinn Flynn                   Support Lead      Edinburgh   22
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 46          Sonya Frost              Software Engineer      Edinburgh   23
# 14         Doris Wilder                Sales Assistant         Sydney   23
# 39    Prescott Bartlett               Technical Author         London   27
# 13         Donna Snider               Customer Support       New York   27
# ...

# %%
df.sort_values(by='Age',ascending=False )
# Out:
#                    Name                       Position         Office  Age  \
# 57                 Name                       Position         Office  Age
# 35        Michael Silva             Marketing Designer         London   66
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 26     Jackson Bradshaw                       Director       New York   65
# 43        Serge Baldwin               Data Coordinator      Singapore   64
# 37         Olivia Liang               Support Engineer      Singapore   64
# 38            Paul Byrd  Chief Financial Officer (CFO)       New York   64
# 17      Garrett Winters                     Accountant          Tokyo   63
# 55        Zenaida Frank              Software Engineer       New York   63
# 53       Vivian Harrell           Financial Controller  San Francisco   62
# 50          Tiger Nixon               System Architect      Edinburgh   61
# ...

# %%
df.sort_values(by=['Name','Age'], ascending= [True,False])
# Out:
#                    Name                       Position         Office  Age  \
# 0            Airi Satou                     Accountant          Tokyo   33
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3         Bradley Greer              Software Engineer         London   41
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
df['Age'].dtype
# Out:
# dtype('O')

# %%
df['Age']=df['Age'].astype(float)

# %%
df.nlargest(10, 'Age')
# Out:
#                   Name                       Position         Office   Age  \
# 2           Ashton Cox        Junior Technical Author  San Francisco  66.0
# 35       Michael Silva             Marketing Designer         London  66.0
# 26    Jackson Bradshaw                       Director       New York  65.0
# 37        Olivia Liang               Support Engineer      Singapore  64.0
# 38           Paul Byrd  Chief Financial Officer (CFO)       New York  64.0
# 43       Serge Baldwin               Data Coordinator      Singapore  64.0
# 17     Garrett Winters                     Accountant          Tokyo  63.0
# 55       Zenaida Frank              Software Engineer       New York  63.0
# 53      Vivian Harrell           Financial Controller  San Francisco  62.0
# 5   Brielle Williamson         Integration Specialist       New York  61.0
#
#     Start date    Salary
# 2   2009-01-12   $86,000
# 35  2012-11-27  $198,500
# 26  2008-09-26  $645,750
# 37  2011-02-03  $234,500
# ...

# %%
df.nsmallest(10, 'Age')
# Out:
#                    Name                     Position         Office   Age  \
# 57                 Name                     Position         Office   0.0
# 48  Tatyana Fitzpatrick            Regional Director         London  19.0
# 45            Shou Itou           Regional Marketing          Tokyo  20.0
# 7          Caesar Vance            Pre-Sales Support       New York  21.0
# 32           Lael Greer        Systems Administrator         London  21.0
# 9          Cedric Kelly  Senior Javascript Developer      Edinburgh  22.0
# 18         Gavin Cortez                  Team Leader  San Francisco  22.0
# 40          Quinn Flynn                 Support Lead      Edinburgh  22.0
# 14         Doris Wilder              Sales Assistant         Sydney  23.0
# 46          Sonya Frost            Software Engineer      Edinburgh  23.0
#
#     Start date    Salary
# 57  Start date    Salary
# 48  2010-03-17  $385,750
# 45  2011-08-14  $163,000
# 7   2011-12-12  $106,450
# ...

# %%
df = pd.read_csv('Data.tsv', delimiter='\t', index_col='Office')
df
# Out:
#                               Name                       Position  Age  \
# Office
# Tokyo                   Airi Satou                     Accountant   33
# London              Angelica Ramos  Chief Executive Officer (CEO)   47
# San Francisco           Ashton Cox        Junior Technical Author   66
# London               Bradley Greer              Software Engineer   41
# San Francisco       Brenden Wagner              Software Engineer   28
# New York        Brielle Williamson         Integration Specialist   61
# London                  Bruno Nash              Software Engineer   38
# New York              Caesar Vance              Pre-Sales Support   21
# New York              Cara Stevens                Sales Assistant   46
# Edinburgh             Cedric Kelly    Senior Javascript Developer   22
# San Francisco      Charde Marshall              Regional Director   36
# San Francisco        Colleen Hurst           Javascript Developer   39
# ...

# %%
df.sort_index()
# Out:
#                               Name                       Position  Age  \
# Office
# Edinburgh          Jennifer Acosta    Junior Javascript Developer   43
# Edinburgh              Quinn Flynn                   Support Lead   22
# Edinburgh              Gavin Joyce                      Developer   42
# Edinburgh             Cedric Kelly    Senior Javascript Developer   22
# Edinburgh              Shad Decker              Regional Director   51
# Edinburgh              Tiger Nixon               System Architect   61
# Edinburgh                 Dai Rios                 Personnel Lead   35
# Edinburgh              Sonya Frost              Software Engineer   23
# Edinburgh           Martena Mccray             Post-Sales support   46
# London         Tatyana Fitzpatrick              Regional Director   19
# London               Michael Silva             Marketing Designer   66
# London                 Jena Gaines                 Office Manager   30
# ...
